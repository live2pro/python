# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
tips = sns.load_dataset("tips")

# %%
sns.stripplot(x="day", y="total_bill", data=tips);

# %%
tix={
"dax":["one","two"],
        "dxy":[100,120]           
    }

# %%
sns.stripplot(x="dax", y="dxy", data=tix);

# %%
sns.stripplot(x="dax", y="dxy", data=tix);

# %%
sns.stripplot(x=dd, y=yy);

# %%
from matplotlib.pyplot import show
ax = sns.barplot(x=dd, y=yy);
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+0.25, height+ 3, '%1.2f'%(height),
                family='sans-serif', fontsize=14, color='darkslategrey')
show()

# %%
sns.set(style="whitegrid")

titanic = sns.load_dataset("titanic")

g = sns.factorplot("class", "survived", "sex",
                    data=titanic, kind="bar",
                    size=6, palette="muted",
                   legend_out=False)
g.despine(left=True)
g.set_ylabels("survival probability")

# %%
budget = budget.sort_values(by='amount',ascending=False)[:10]

# %%
bar_chart = pygal.Bar(style=LightStyle, width=800, height=600,
                      legend_at_bottom=True, human_readable=True,
                      title='MN Capital Budget - 2014')

# %%
for index, row in budget.iterrows():
    bar_chart.add(row["detail"], row["amount"])

# %%
bar_chart.render_in_browser()
# Out:
# file://C:/Users/PRYN~1.FTP/AppData/Local/Temp/tmpa7rcf4hi.html
