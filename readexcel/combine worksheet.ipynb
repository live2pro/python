# %%
import pandas as pd

# %%
workbook="4weeek-data.xlsx"

# %%
single_df = pd.read_excel(workbook, sheet_name='week1')

# %%
single_df
# Out:
#     id  type  cost
# 0    1     4    80
# 1    2     9    42
# 2    3     2    98
# 3    4     1    55
# 4    5     2    42
# 5    6     7    45
# 6    7     1    96
# 7    8     4    36
# 8    9     9    86
# 9   10     1    44
# 10  11     3    37
# 11  12     1    52
# 12  13     2    40
# 13  14     9    97
# 14  15     1    93
# 15  16     5    81
# 16  17     1    93
# 17  18     6    66
# 18  19     5    83
# 19  20     6    40

# %%
all_dfs = pd.read_excel(workbook, sheet_name=None)

# %%
import pandas as pd

workbook_url = 'https://github.com/chris1610/pbpython/raw/master/data/2018_Sales_Total_Tabs.xlsx'
single_df = pd.read_excel(workbook_url, sheet_name='Sheet1')

# %%
single_df
# Out:
#     account number                             name       sku  quantity  \
# 0           412290                    Jerde-Hilpert  S2-77896        43
# 1           383080                         Will LLC  S1-93683        28
# 2           729833                        Koepp Ltd  S1-30248        13
# 3           424914                    White-Trantow  S2-82423        38
# 4           672390                  Kuhn-Gusikowski  S1-50961        34
# 5           239344                       Stokes LLC  S2-10342        34
# 6           218895                        Kulas Inc  S2-34077        30
# 7           672390                  Kuhn-Gusikowski  B1-05914        25
# 8           740150                       Barton LLC  S1-82801        29
# 9           218895                        Kulas Inc  B1-20000        23
# 10          257198  Cronin, Oberbrunner and Spencer  S1-30248        14
# 11          672390                  Kuhn-Gusikowski  S2-83881        26
# ...

# %%
all_dfs = pd.read_excel(workbook, sheet_name=None)

# %%
all_dfs
# Out:
#     id  type  cost
# 0    1     4    80
# 1    2     9    42
# 2    3     2    98
# 3    4     1    55
# 4    5     2    42
# 5    6     7    45
# 6    7     1    96
# 7    8     4    36
# 8    9     9    86
# 9   10     1    44
# 10  11     3    37
# 11  12     1    52
# 12  13     2    40
# 13  14     9    97
# 14  15     1    93
# 15  16     5    81
# 16  17     1    93
# 17  18     6    66
# 18  19     5    83
# 19  20     6    40
