# %%
import pythainlp

# %%
pythainlp.__version__
# Out:
# '2.0.7'

# %%
from pythainlp import sent_tokenize, word_tokenize

text = "ฉันรักภาษาไทย     เพราะฉันใช้ภาษาไทย "

print("sent_tokenize:", sent_tokenize(text))
print("word_tokenize:", word_tokenize(text))
print("word_tokenize, without whitespace:", word_tokenize(text, keep_whitespace=False))
# Out:
# sent_tokenize: ['ฉันรักภาษาไทย', 'เพราะฉันใช้ภาษาไทย']
# word_tokenize: ['ฉัน', 'รัก', 'ภาษาไทย', '     ', 'เพราะ', 'ฉัน', 'ใช้', 'ภาษาไทย', ' ']
# word_tokenize, without whitespace: ['ฉัน', 'รัก', 'ภาษาไทย', 'เพราะ', 'ฉัน', 'ใช้', 'ภาษาไทย']

# %%
news="เมื่อวันที่ 30 พ.ย.62 นายธนกร วังบุญคงชนะ โฆษกพรรคพลังประชารัฐ กล่าวถึงกรณีที่นายธนาธร จึงรุ่งเรืองกิจ หัวหน้าพรรคอนาคตใหม่ ลาออกจากตำแหน่งกรรมาธิการงบประมาณฯ และอนุกรรมาธิการงบประมาณฯ ว่า ดูเหตุผลการลาออกแล้วไม่สมเหตุสมผล นายธนากรบอกว่าลาออกเพราะมีคนไม่ต้องการเห็นนายธนาธรในสภาฯ ซึ่งไม่น่าจะใช่ เพราะนายธนาธรเข้ามาทำงานในกรรมาธิการฯ โดยทุกอย่างเป็นไปด้วยดี ไม่ได้มีปัญหาอะไร เป็นการทำงานตรวจสอบงบประมาณตามที่พรรคอนาคตใหม่ต้องการ ทั้งนี้ ตนมองว่านายธนาธรไม่มีความรับผิดชอบมากกว่า เพราะการทำงานในกรรมาธิการงบประมาณฯ มีการประชุมจนดึกดื่นทุกวัน และเหนื่อยมาก นายธนาธรคงทนไม่ไหวกับงานหนักและต้องใช้สมองคิดตลอดเวลา จึงลาออก ซึ่งเป็นการไม่รับผิดชอบต่อประชาชน และไม่อยากให้นำมาเป็นข้ออ้างเพื่อโจมตีรัฐบาลอีก เพราะสิ่งที่นายธนาธรพูดทุกครั้งก็ยิ่งเหมือนแผ่นเสียงตกร่อง ไม่ว่าจะเป็นสืบทอดอำนาจเผด็จการ ทั้งๆ ที่รัฐบาลมาจากการเลือกตั้งตามระบอบประชาธิปไตยแล้ว"

# %%
print("sent_tokenize:", sent_tokenize(news))
# Out:
# sent_tokenize: ['เมื่อวันที่', '30', 'พ.ย.62', 'นายธนกร', 'วังบุญคงชนะ', 'โฆษกพรรคพลังประชารัฐ', 'กล่าวถึงกรณีที่นายธนาธร', 'จึงรุ่งเรืองกิจ', 'หัวหน้าพรรคอนาคตใหม่', 'ลาออกจากตำแหน่งกรรมาธิการงบประมาณฯ', 'และอนุกรรมาธิการงบประมาณฯ', 'ว่า', 'ดูเหตุผลการลาออกแล้วไม่สมเหตุสมผล', 'นายธนากรบอกว่าลาออกเพราะมีคนไม่ต้องการเห็นนายธนาธรในสภาฯ', 'ซึ่งไม่น่าจะใช่', 'เพราะนายธนาธรเข้ามาทำงานในกรรมาธิการฯ', 'โดยทุกอย่างเป็นไปด้วยดี', 'ไม่ได้มีปัญหาอะไร', 'เป็นการทำงานตรวจสอบงบประมาณตามที่พรรคอนาคตใหม่ต้องการ', 'ทั้งนี้', 'ตนมองว่านายธนาธรไม่มีความรับผิดชอบมากกว่า', 'เพราะการทำงานในกรรมาธิการงบประมาณฯ', 'มีการประชุมจนดึกดื่นทุกวัน', 'และเหนื่อยมาก', 'นายธนาธรคงทนไม่ไหวกับงานหนักและต้องใช้สมองคิดตลอดเวลา', 'จึงลาออก', 'ซึ่งเป็นการไม่รับผิดชอบต่อประชาชน', 'และไม่อยากให้นำมาเป็นข้ออ้างเพื่อโจมตีรัฐบาลอีก', 'เพราะสิ่งที่นายธนาธรพูดทุกครั้งก็ยิ่งเหมือนแผ่นเสียงตกร่อง', 'ไม่ว่าจะเป็นสืบทอดอำนาจเผด็จการ', 'ทั้งๆ', 'ที่รัฐบาลมาจากการเลือกตั้งตามระบอบประชาธิปไตยแล้ว']

# %%
print("word_tokenize, without whitespace:", word_tokenize(news, keep_whitespace=False))
# Out:
# word_tokenize, without whitespace: ['เมื่อ', 'วันที่', '30', 'พ.ย.', '62', 'นาย', 'ธน', 'กร', 'วัง', 'บุญ', 'คง', 'ชนะ', 'โฆษก', 'พรรค', 'พลัง', 'ประชา', 'รัฐ', 'กล่าวถึง', 'กรณีที่', 'นาย', 'ธนา', 'ธร', 'จึง', 'รุ่งเรือง', 'กิจ', 'หัวหน้าพรรค', 'อนาคต', 'ใหม่', 'ลา', 'ออกจาก', 'ตำแหน่ง', 'กรรมาธิการ', 'งบประมาณ', 'ฯ', 'และ', 'อนุกรรมาธิการ', 'งบประมาณ', 'ฯ', 'ว่า', 'ดู', 'เหตุผล', 'การ', 'ลาออก', 'แล้ว', 'ไม่', 'สมเหตุสมผล', 'นาย', 'ธนา', 'กร', 'บอ', 'กว่า', 'ลาออก', 'เพราะ', 'มี', 'คน', 'ไม่ต้องการ', 'เห็น', 'นาย', 'ธนา', 'ธร', 'ใน', 'สภา', 'ฯ', 'ซึ่ง', 'ไม่', 'น่าจะ', 'ใช่', 'เพราะ', 'นาย', 'ธนา', 'ธร', 'เข้ามา', 'ทำงาน', 'ใน', 'กรรมาธิการ', 'ฯ', 'โดย', 'ทุกอย่าง', 'เป็นไป', 'ด้วยดี', 'ไม่ได้', 'มีปัญหา', 'อะไร', 'เป็น', 'การทำงาน', 'ตรวจสอบ', 'งบประมาณ', 'ตามที่', 'พรรค', 'อนาคต', 'ใหม่', 'ต้องการ', 'ทั้งนี้', 'ตน', 'มองว่า', 'นาย', 'ธนา', 'ธร', 'ไม่มี', 'ความรับผิดชอบ', 'มากกว่า', 'เพราะ', 'การทำงาน', 'ใน', 'กรรมาธิการ', 'งบประมาณ', 'ฯ', 'มี', 'การประชุม', 'จน', 'ดึกดื่น', 'ทุกว
# ...

# %%
from pythainlp.tag.named_entity import ThaiNameTagger

# %%
ner = ThaiNameTagger()

# %%
ner.get_ner("15 ก.ย. 61 ทดสอบระบบเวลา 14:49 น. เดินทางจากกทม.ไปจังหวัดกำแพงเพชร ตั๋วราคา 297 บาท")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-5f9c01120458> in <module>
# ----> 1 ner.get_ner("15 ก.ย. 61 ทดสอบระบบเวลา 14:49 น. เดินทางจากกทม.ไปจังหวัดกำแพงเพชร ตั๋วราคา 297 บาท")
#
# E:\Python\lib\site-packages\pythainlp\tag\named_entity.py in get_ner(self, text, pos)
#     123         )
#     124         self.__x_test = self.__extract_features(self.__pos_tags)
# --> 125         self.__y = self.crf.predict_single(self.__x_test)
#     126
#     127         if pos:
#
# E:\Python\lib\site-packages\sklearn_crfsuite\estimator.py in predict_single(self, xseq)
#     365
#     366         """
# --> 367         return self.tagger_.tag(xseq)
#     368
#     369     def predict_marginals(self, X):
#
# AttributeError: 'NoneType' object has no attribute 'tag'
